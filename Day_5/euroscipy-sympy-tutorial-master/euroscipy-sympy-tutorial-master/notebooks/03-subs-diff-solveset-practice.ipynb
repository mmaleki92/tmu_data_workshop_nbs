# %%
from sympy import *
init_printing()
x, y, z, a, b, c = symbols('x,y,z,a,b,c')

# %load_ext exercise_evaluate
# Out:
# The exercise_evaluate module is not an IPython extension.

# %% [markdown]
# Let's put what we have learned so far (subs, diff, solveset) to test

# %%
def evaluate(exprs, x, x0):
    """
    Differentiate each expression in exprs  and evaluate at the point x = x0.

    >>> x, y = symbols('x y')
    >>> exprs = [x**2, cos(x), x*y]
    >>> evaluate(exprs, x, 1)
    [2, -sin(1), y]
    >>> evaluate(exprs, y, 0)
    [0, 0, x]
    """
    ans = [expr.diff(x).subs({x: x0}) for expr in exprs]  # EXERCISE: [expr.diff(x).subs({x: x0}) for expr in exprs]
    return ans

# %%
# %load exercise_evaluate.py
def evaluate(exprs, x, x0):
    """
    Differentiate each expression in exprs and evaluate at the point x = x0.

    >>> x, y = symbols('x y')
    >>> exprs = [x**2, cos(x), x*y]
    >>> evaluate(exprs, x, 1)
    [2, -sin(1), y]
    >>> evaluate(exprs, y, 0)
    [0, 0, x]
    """
    ans = ???
    return ans

# %%
exprs = [x**2, cos(x), x*y]

# %%
evaluate(exprs, x, 1)
# Out:
# [2, -sin(1), y]

# %%
evaluate(exprs, y, 1)
# Out:
# [0, 0, x]

# %% [markdown]
# ### Exercise

# %% [markdown]
# Write a function that computes the [quadratic equation](http://en.wikipedia.org/wiki/Quadratic_equation).

# %%
# %load exercise_quadratic.py
def quadratic():
    ans = ???
    return ans

# %%
def quadratic():
    ans = solveset(a*x**2 + b*x + c, x)  # EXERCISE: solveset(a*x**2 + b*x + c, x)
    return ans
quadratic()
# Out:
# ⎧           _____________             _____________⎫
# ⎪          ╱           2             ╱           2 ⎪
# ⎨   b    ╲╱  -4⋅a⋅c + b       b    ╲╱  -4⋅a⋅c + b  ⎬
# ⎪- ─── - ────────────────, - ─── + ────────────────⎪
# ⎩  2⋅a         2⋅a           2⋅a         2⋅a       ⎭

# %% [markdown]
# Write a function that computes the general solution to the cubic $x^3 + ax^2 + bx + c$.

# %%
# %load exercise_cubic.py
def cubic():
    ans = ???
    return ans
cubic()

# %%
def cubic():
    ans = solveset(x**3 + a*x**2 + b*x + c, x)  # EXERCISE: solveset(x**3 + a*x**2 + b*x + c, x)
    return ans
cubic()
# Out:
# ⎧
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪                                          2
# ⎪  a                                      a  - 3⋅b
# ⎨- ─ - ───────────────────────────────────────────────────────────────────────
# ⎪  3            ______________________________________________________________
# ⎪              ╱                         _____________________________________
# ⎪             ╱                         ╱               3
# ⎪            ╱                         ╱      ⎛ 2      ⎞    ⎛   3
# ⎪           ╱     3   9⋅a⋅b   27⋅c   ╲╱   - 4⋅⎝a  - 3⋅b⎠  + ⎝2⋅a  - 9⋅a⋅b + 27
# ⎪      3⋅3 ╱     a  - ───── + ──── + ─────────────────────────────────────────
# ⎩        ╲╱             2      2                           2
#
#                 ______________________________________________________________
#                ╱                         _____________________________________
#               ╱                         ╱               3
#              ╱                         ╱      ⎛ 2      ⎞    ⎛   3
#             ╱     3   9⋅a⋅b   27⋅c   ╲╱   - 4⋅⎝a  - 3⋅b⎠  + ⎝2⋅a  - 9⋅a⋅b + 27
#          3 ╱     a  - ───── + ──── + ─────────────────────────────────────────
#          ╲╱             2      2                           2
# ────── - ─────────────────────────────────────────────────────────────────────
# ______                                        3
# _____
#    2
#   ⎞
# ⋅c⎠
# ─────
#
#
# ______
# _____
#    2
#   ⎞
# ⋅c⎠
# ─────                                                   2
#           a                                            a  - 3⋅b
# ──────, - ─ - ────────────────────────────────────────────────────────────────
#           3                         __________________________________________
#                                    ╱                         _________________
#                                   ╱                         ╱               3
#                                  ╱                         ╱      ⎛ 2      ⎞
#                 ⎛  1   √3⋅ⅈ⎞    ╱     3   9⋅a⋅b   27⋅c   ╲╱   - 4⋅⎝a  - 3⋅b⎠
#               3⋅⎜- ─ - ────⎟⋅3 ╱     a  - ───── + ──── + ─────────────────────
#                 ⎝  2    2  ⎠ ╲╱             2      2
#
#                                                  _____________________________
#                                                 ╱                         ____
#                                                ╱                         ╱
#                                               ╱                         ╱
#                              ⎛  1   √3⋅ⅈ⎞    ╱     3   9⋅a⋅b   27⋅c   ╲╱   - 4
#                              ⎜- ─ - ────⎟⋅3 ╱     a  - ───── + ──── + ────────
#                              ⎝  2    2  ⎠ ╲╱             2      2
# ────────────────────────── - ─────────────────────────────────────────────────
# __________________________                                              3
# _________________________
#                        2
#   ⎛   3               ⎞
# + ⎝2⋅a  - 9⋅a⋅b + 27⋅c⎠
# ─────────────────────────
#  2
#
# _______________________________________
# ______________________________________
#            3                        2
#  ⎛ 2      ⎞    ⎛   3               ⎞
# ⋅⎝a  - 3⋅b⎠  + ⎝2⋅a  - 9⋅a⋅b + 27⋅c⎠
# ──────────────────────────────────────
#               2                            a
# ───────────────────────────────────────, - ─ - ───────────────────────────────
#                                            3                         _________
#                                                                     ╱
#                                                                    ╱
#                                                                   ╱
#                                                  ⎛  1   √3⋅ⅈ⎞    ╱     3   9⋅a
#                                                3⋅⎜- ─ + ────⎟⋅3 ╱     a  - ───
#                                                  ⎝  2    2  ⎠ ╲╱             2
#
#
#
#
#
#                                                               ⎛  1   √3⋅ⅈ⎞
#            2                                                  ⎜- ─ + ────⎟⋅3 ╱
#           a  - 3⋅b                                            ⎝  2    2  ⎠ ╲╱
# ─────────────────────────────────────────────────────────── - ────────────────
# ___________________________________________________________
#                 __________________________________________
#                ╱               3                        2
#               ╱      ⎛ 2      ⎞    ⎛   3               ⎞
# ⋅b   27⋅c   ╲╱   - 4⋅⎝a  - 3⋅b⎠  + ⎝2⋅a  - 9⋅a⋅b + 27⋅c⎠
# ── + ──── + ──────────────────────────────────────────────
#       2                           2
#
#     ____________________________________________________________________⎫
#    ╱                         __________________________________________ ⎪
#   ╱                         ╱               3                        2  ⎪
#  ╱                         ╱      ⎛ 2      ⎞    ⎛   3               ⎞   ⎪
# ╱     3   9⋅a⋅b   27⋅c   ╲╱   - 4⋅⎝a  - 3⋅b⎠  + ⎝2⋅a  - 9⋅a⋅b + 27⋅c⎠   ⎪
#      a  - ───── + ──── + ────────────────────────────────────────────── ⎪
#             2      2                           2                        ⎪
# ────────────────────────────────────────────────────────────────────────⎬
#                            3                                            ⎪
#                                                                         ⎪
#                                                                         ⎪
#                                                                         ⎪
#                                                                         ⎪
#                                                                         ⎪
#                                                                         ⎭
